# %% [raw]
# ---
# toc: False
# comments: True
# layout: post
# title: Study Plan for AP CSP
# permalink: 2025-04-22-Study-plan
# author: Hithin
# ---

# %% [markdown]
# <html lang="en">
# <head>
#   <meta charset="UTF-8">
#   <meta name="viewport" content="width=device-width, initial-scale=1.0">
#   <title>AP CSP Study Plan</title>
#   <style>
#     body {
#       font-family: 'Segoe UI', sans-serif;
#       background: #f7faff;
#       color: #333;
#       padding: 20px;
#     }
#     h1, h2, h3 {
#       color: #007acc;
#     }
#     .section {
#       margin-bottom: 30px;
#       padding: 20px;
#       background: #ffffff;
#       border-left: 6px solid #007acc;
#       border-radius: 8px;
#       box-shadow: 0 2px 8px rgba(0, 0, 0, 0.1);
#     }
#     .highlight {
#       background: #e0f7fa;
#       padding: 10px;
#       border-radius: 6px;
#       margin: 10px 0;
#     }
#     .calendar {
#       display: grid;
#       grid-template-columns: repeat(7, 1fr);
#       gap: 10px;
#       background: #f1f1f1;
#       padding: 10px;
#       border-radius: 10px;
#     }
#     .day {
#       background: #ffffff;
#       border: 2px solid #007acc;
#       border-radius: 10px;
#       padding: 10px;
#       text-align: center;
#       font-size: 0.9em;
#     }
#     .study-topic {
#       margin-top: 5px;
#       font-weight: bold;
#       color: #005b99;
#     }
#     .color-box {
#       display: inline-block;
#       width: 12px;
#       height: 12px;
#       margin-right: 5px;
#       border-radius: 3px;
#     }
#     .legend {
#       display: flex;
#       gap: 20px;
#       margin-top: 10px;
#     }
#   </style>
# </head>
# <body>
#
#   <h1>📅 AP CSP Exam Study Plan (April 21 - May 15)</h1>
#
#   <div class="section">
#     <h2>📚 Study Topics Covered</h2>
#     <ul>
#       <li>Beneficial and Harmful Effects of Technology</li>
#       <li>Artificial Intelligence, Drones, and Gene Editing</li>
#       <li>Cyberbullying and Mental Health</li>
#       <li>Computing Bias: Algorithmic, Data, and Cognitive</li>
#       <li>Explicit vs Implicit Data</li>
#       <li>Mitigating Bias in Computing</li>
#     </ul>
#   </div>
#
#   <div class="section">
#     <h2>📆 Study Calendar</h2>
#     <div class="legend">
#       <div><span class="color-box" style="background: #a8dadc;"></span>Review Notes</div>
#       <div><span class="color-box" style="background: #fcbf49;"></span>Practice MCQs</div>
#       <div><span class="color-box" style="background: #ff6b6b;"></span>Project Review</div>
#       <div><span class="color-box" style="background: #80ed99;"></span>Flashcards/Recap</div>
#     </div>
#     <div class="calendar">
#       <!-- Calendar Days with Activities -->
#       <div class="day">Apr 21<div class="study-topic" style="color:#a8dadc;">Review Notes</div></div>
#       <div class="day">Apr 22<div class="study-topic" style="color:#fcbf49;">Practice MCQs</div></div>
#       <div class="day">Apr 23<div class="study-topic" style="color:#ff6b6b;">Project Review</div></div>
#       <div class="day">Apr 24<div class="study-topic" style="color:#80ed99;">Flashcards</div></div>
#       <div class="day">Apr 25<div class="study-topic" style="color:#a8dadc;">Bias in Computing</div></div>
#       <div class="day">Apr 26<div class="study-topic" style="color:#fcbf49;">MCQ: Cyberbullying</div></div>
#       <div class="day">Apr 27<div class="study-topic" style="color:#80ed99;">Flashcards</div></div>
#       <div class="day">Apr 28<div class="study-topic" style="color:#ff6b6b;">Project Reflection</div></div>
#       <div class="day">Apr 29<div class="study-topic" style="color:#fcbf49;">Practice Quiz</div></div>
#       <div class="day">Apr 30<div class="study-topic" style="color:#a8dadc;">Review Tech Impacts</div></div>
#       <div class="day">May 1<div class="study-topic" style="color:#fcbf49;">Practice MCQs</div></div>
#       <div class="day">May 2<div class="study-topic" style="color:#80ed99;">Flashcards</div></div>
#       <div class="day">May 3<div class="study-topic" style="color:#ff6b6b;">Practice Project Response</div></div>
#       <div class="day">May 4<div class="study-topic" style="color:#a8dadc;">Bias Deep Dive</div></div>
#       <div class="day">May 5<div class="study-topic" style="color:#fcbf49;">Timed MCQ Set</div></div>
#       <div class="day">May 6<div class="study-topic" style="color:#80ed99;">Flashcards</div></div>
#       <div class="day">May 7<div class="study-topic" style="color:#ff6b6b;">Final Project Touchup</div></div>
#       <div class="day">May 8<div class="study-topic" style="color:#fcbf49;">Review Key Terms</div></div>
#       <div class="day">May 9<div class="study-topic" style="color:#a8dadc;">Study Group Q&A</div></div>
#       <div class="day">May 10<div class="study-topic" style="color:#ff6b6b;">Project Self Grade</div></div>
#       <div class="day">May 11<div class="study-topic" style="color:#fcbf49;">MCQ Final Practice</div></div>
#       <div class="day">May 12<div class="study-topic" style="color:#80ed99;">Flashcards</div></div>
#       <div class="day">May 13<div class="study-topic" style="color:#a8dadc;">Full Review</div></div>
#       <div class="day">May 14<div class="study-topic" style="color:#fcbf49;">Exam Readiness</div></div>
#       <div class="day">May 15<div class="study-topic" style="color:#80ed99;">AP CSP EXAM ✅</div></div>
#     </div>
#   </div>
#
#   <div class="section">
#     <h2>💡 Study Tips</h2>
#     <ul>
#       <li>Focus on one main topic each day. Avoid multitasking.</li>
#       <li>Use color-coded flashcards to reinforce terms.</li>
#       <li>Form a study group to quiz each other and share notes.</li>
#       <li>Practice with real AP MCQ samples under timed conditions.</li>
#       <li>Review your Performance Task (Create PT) and self-evaluate with the rubric.</li>
#     </ul>
#   </div>
#
# </body>
# </html>
