# %% [raw]
# ---
# toc: False
# comments: True
# layout: post
# title: Night at the Museum
# permalink: N@tM-tri3
# author: Hithin
# ---

# %% [markdown]
# <html lang="en">
# <head>
#   <meta charset="UTF-8" />
#   <meta name="viewport" content="width=device-width, initial-scale=1.0" />
#   <title>Night at the Museum - CSP Project Showcase</title>
#   <style>
#     body {
#       font-family: 'Segoe UI', sans-serif;
#       background-color: #f7f9fc;
#       margin: 0;
#       padding: 0;
#       color: #333;
#     }
#
#     header {
#       background: linear-gradient(to right, #6a11cb, #2575fc);
#       color: white;
#       padding: 2rem;
#       text-align: center;
#     }
#
#     section {
#       padding: 2rem;
#       max-width: 900px;
#       margin: auto;
#     }
#
#     .screenshot {
#       margin-bottom: 2rem;
#     }
#
#     img {
#       width: 100%;
#       border-radius: 10px;
#       box-shadow: 0 4px 10px rgba(0,0,0,0.1);
#     }
#
#     h2, h3 {
#       color: #2575fc;
#     }
#
#     footer {
#       text-align: center;
#       background: #e0e7f1;
#       padding: 1rem;
#       color: #555;
#     }
#   </style>
# </head>
# <body>
#
# <header>
#   <h1>🎉 Night at the Museum: Project Showcase</h1>
#   <p>A Celebration of Creativity, Coding, and Collaboration</p>
# </header>
#
# <section>
#   <h2>Overview</h2>
#   <p>Night at the Museum was an amazing opportunity to present our final projects, interact with others, and experience the creativity that everyone brought to the table. I had a chance to share our team’s work and see some really impressive ideas in action.</p>
#
#   <h2>📌 My Experience</h2>
#   <p>During the event, I explained the project my team and I worked on to several attendees. I also created a LinkedIn post to document the experience and earn some extra credit.</p>
#
#   <div class="screenshot">
#     <h3>✅ LinkedIn Post for Extra Credit</h3>
#     <img src="{{site.baseurl}}/images/CSP_MCQ/Screenshot 2025-06-10 at 10.26.36 AM.jpeg" alt="LinkedIn Post">
#   </div>
#
#   <div class="screenshot">
#     <h3>🎤 Presenting My Team's Project</h3>
#     <img src="{{site.baseurl}}/images/CSP_MCQ/Screenshot 2025-06-10 at 10.26.54 AM.jpeg" alt="Me Explaining Project">
#   </div>
#
#   <h2>🌟 Other Projects I Loved</h2>
#
#   <div class="screenshot">
#     <h3>🎮 CSS Game with Stunning UI</h3>
#     <img src="{{site.baseurl}}/images/CSP_MCQ/Screenshot 2025-06-10 at 10.27.06 AM.jpeg" alt="Cool CSS Game">
#     <p>This project stood out with its interactive gameplay and beautiful CSS styling. It was both fun and well-structured.</p>
#   </div>
#
#   <div class="screenshot">
#     <h3>🧑‍🏫 Educational Website for Teachers</h3>
#     <img src="{{site.baseurl}}/images/CSP_MCQ/Screenshot 2025-06-10 at 10.27.35 AM.jpeg" alt="Website for Teachers">
#     <p>Great functionality with a polished user interface — an awesome tool for educators to use during lessons.</p>
#   </div>
#
#   <div class="screenshot">
#     <h3>📈 Stock Market Website</h3>
#     <img src="{{site.baseurl}}/images/CSP_MCQ/Screenshot 2025-06-10 at 10.27.45 AM.jpeg" alt="Cool Stock Website">
#     <p>This one combined a clean layout with helpful financial tools, showing how powerful front-end development can be when paired with practical utility.</p>
#   </div>
# </section>
#
# <footer>
#   &copy; 2025 Hithin P | Documenting Passion, Progress, and Projects 🚀
# </footer>
#
# </body>
# </html>
