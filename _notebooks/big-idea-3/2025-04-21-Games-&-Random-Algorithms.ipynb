# %% [raw]
# ---
# toc: False
# comments: True
# layout: post
# title: Simulation/Games and Random Algorithms
# permalink: Games-&-Random-Algorithms
# author: Hithin
# ---

# %% [markdown]
# <html lang="en">
# <head>
#   <meta charset="UTF-8" />
#   <meta name="viewport" content="width=device-width, initial-scale=1.0" />
#   <title>Random Number Simulations</title>
#   <style>
#     body {
#       font-family: 'Segoe UI', sans-serif;
#       background: #f0f8ff;
#       color: #333;
#       padding: 20px;
#     }
#     h1, h2 {
#       color: #2a7bdc;
#     }
#     code, pre {
#       background: #eef;
#       padding: 10px;
#       display: block;
#       border-radius: 5px;
#     }
#     .section {
#       margin-bottom: 40px;
#       border-left: 6px solid #2a7bdc;
#       padding-left: 15px;
#       background-color: #fff;
#       padding: 20px;
#       border-radius: 8px;
#       box-shadow: 0 2px 5px rgba(0,0,0,0.1);
#     }
#     .output {
#       background: #222;
#       color: #0f0;
#       padding: 10px;
#       font-family: monospace;
#       white-space: pre-wrap;
#       border-radius: 5px;
#     }
#   </style>
# </head>
# <body>
#
#   <h1>🎲 Random Number Simulations in Python</h1>
#
#   <div class="section">
#     <h2>1️⃣ Random Integers</h2>
#     <p>Using <code>random.randint(a, b)</code> to generate numbers between two values:</p>
#     <pre><code>Random number between 1-10: 6
# Random number between 0-1: 0
# Random number between 1-6: 2</code></pre>
#   </div>
#
#   <div class="section">
#     <h2>🪙 Coin Flip Simulation</h2>
#     <p>Simulating a coin flip 10 times:</p>
#     <div class="output">
# Flip 1: Tails
# Flip 2: Tails
# Flip 3: Heads
# Flip 4: Tails
# Flip 5: Heads
# Flip 6: Heads
# Flip 7: Tails
# Flip 8: Tails
# Flip 9: Tails
# Flip 10: Tails
#     </div>
#   </div>
#
#   <div class="section">
#     <h2>🎡 Weighted Color Spinner</h2>
#     <p>Simulates a spinner with different probabilities for each color.</p>
#     <div class="output">
# Purple: 4 times (20.0%)
# Green: 6 times (30.0%)
# Blue: 6 times (30.0%)
# Orange: 3 times (15.0%)
# Red: 1 times (5.0%)
#     </div>
#   </div>
#
#   <div class="section">
#     <h2>🔮 Magic 8-Ball</h2>
#     <p>Returns Yes (~50%), No (~25%), or Ask again later (~25%):</p>
#     <div class="output">
# Magic 8-Ball says: Yes
# Magic 8-Ball says: No
# Magic 8-Ball says: Yes
# Magic 8-Ball says: Ask again later
# Magic 8-Ball says: Yes
# Magic 8-Ball says: Ask again later
# Magic 8-Ball says: No
# Magic 8-Ball says: Yes
# Magic 8-Ball says: Yes
# Magic 8-Ball says: Ask again later
#     </div>
#   </div>
#   <div class="section">
#     <h2>🚦 Traffic Light Simulation</h2>
#     <p>Simulates traffic lights with specific durations:</p>
#     <div class="output">
# Time 0: Green
# Time 1: Green
# Time 2: Green
# Time 3: Green
# Time 4: Green
# Time 5: Yellow
# Time 6: Yellow
# Time 7: Red
# Time 8: Red
# Time 9: Red
# Time 10: Red
# Time 11: Green
# Time 12: Green
# Time 13: Green
# Time 14: Green
# Time 15: Green
# Time 16: Yellow
# Time 17: Yellow
# Time 18: Red
# Time 19: Red
#     </div>
#   </div>
#   <div class="section">
#     <h2>🏀 Bouncing Ball Simulation (No Randomness)</h2>
#     <p>Uses physics formulas to simulate a ball bouncing under gravity. Run this part in a Jupyter Notebook to see animation:</p>
#     <pre><code>import matplotlib.pyplot as plt
# import matplotlib.animation as animation
# from IPython.display import HTML
# # Simulation parameters
# gravity = -9.8
# step = 0.05
# restitution = 0.75
# y = 10
# v = 0
# def update_physics(y, v):
#     v += gravity * step
#     y += v * step
#     if y <= 0:
#         y = 0
#         v = -v * restitution
#     return y, v
#
# fig, ax = plt.subplots()
# ball, = plt.plot([], [], 'o', markersize=20)
# ax.set_xlim(0, 1)
# ax.set_ylim(0, 12)
# ax.set_title("Bouncing Ball Simulation")
# ax.get_xaxis().set_visible(False)
# ax.get_yaxis().set_visible(False)
#
# def init():
#     ball.set_data([0.5], [y])
#     return ball,
#
# def animate(i):
#     global y, v
#     y, v = update_physics(y, v)
#     ball.set_data([0.5], [y])
#     return ball,
#
# ani = animation.FuncAnimation(fig, animate, init_func=init,
#                               frames=200, interval=50, blit=True)
#
# HTML(ani.to_jshtml())</code></pre>
#   </div>
#
# </body>
# </html>
